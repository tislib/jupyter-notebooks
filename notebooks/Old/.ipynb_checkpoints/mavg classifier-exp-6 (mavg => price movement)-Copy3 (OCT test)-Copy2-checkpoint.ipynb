# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline 
plt.rcParams['figure.figsize'] = [15, 5]

# %%
# %load_ext autoreload
# %autoreload 2
# %run '../main.py'

# %%
dataSetOps = DataSetOps()

dataSetOps.import_years(2010, 2017)

dataSetOps.prepare()


df = dataSetOps.df

dataSetOps2 = DataSetOps()

dataSetOps2.import_years(2018, 2018)

dataSetOps2.prepare()


df2 = dataSetOps2.df

# %%
# variables
mavgl = 30
window = 20
epilson = 0.0001
ew = 3 #3

# %%
from lib.predictstrategy import st1_max_mean
from lib.predictstrategy import st1_max_min

value_real_func = st1_max_mean
value_real_func2 = st1_max_mean

# %%
mavgl_i = mavgl
mavgl = str(mavgl)
df['f_mavg' + mavgl] = df['mavg' + mavgl].shift(-window).rolling(window=mavgl_i+window).mean()

df['value'] = df['f_mavg' + mavgl] - df['mavg' + mavgl] > epilson

df['value_real'] = value_real_func2(df, window, epilson * ew)

df[['price', 'mavg' + mavgl, 'mavg10', 'f_mavg' + mavgl]].head(1000).plot()

# %%
df['value'].astype(int).hist()
print(len(df[df['value']]) / (len(df)))
# Out:
# 0.23042091460874192

# %%
X = df[['price', 'mavg10', 'mavg20', 'mavg50', 'mavg80', 'mavg100', 'mavg1000']]
Y = df['value']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.1)

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Importing the Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense

    
#Initializing Neural Network
classifier = Sequential()

class1 = Dense(output_dim = 16, init = 'uniform', activation = 'relu', input_dim = 7)
class2 = Dense(output_dim = 16, init = 'uniform', activation = 'relu')
class3 = Dense(output_dim = 16, init = 'uniform', activation = 'relu')
# Adding the input layer and the first hidden layer
classifier.add(class1)
# Adding the second hidden layer
classifier.add(class2)
classifier.add(class3)
# Adding the output layer
classifier.add(Dense(output_dim = 1, init = 'uniform', activation = 'sigmoid'))

# Compiling Neural Network
from keras import metrics
metric_names = [metrics.mae, 'accuracy']
classifier.compile(optimizer='adam', loss = 'mean_squared_error', metrics=metric_names)


# Fitting our model 
classifier.fit(X_train, y_train, batch_size = 20, epochs = 5)
import random
classifier.save("/tmp/mavg_classifier_" + str(random.randint(100000, 999999)))
# Out:
# Using TensorFlow backend.
# /home/taleh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", input_dim=7, units=16, kernel_initializer="uniform")`
#   # Remove the CWD from sys.path while we load stuff.
# /home/taleh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=16, kernel_initializer="uniform")`
#   # This is added back by InteractiveShellApp.init_path()
# /home/taleh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:12: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=16, kernel_initializer="uniform")`
#   if sys.path[0] == '':
# /home/taleh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:19: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=1, kernel_initializer="uniform")`
# Epoch 1/5
# 2641896/2641896 [==============================] - 56s 21us/step - loss: 0.1495 - mean_absolute_error: 0.2935 - acc: 0.8007
# Epoch 2/5
# 2641896/2641896 [==============================] - 56s 21us/step - loss: 0.1297 - mean_absolute_error: 0.2508 - acc: 0.8261
# Epoch 3/5
# 2641896/2641896 [==============================] - 56s 21us/step - loss: 0.1237 - mean_absolute_error: 0.2391 - acc: 0.8341
# Epoch 4/5
# 2641896/2641896 [==============================] - 56s 21us/step - loss: 0.1195 - mean_absolute_error: 0.2310 - acc: 0.8395
# Epoch 5/5
# 2641896/2641896 [==============================] - 56s 21us/step - loss: 0.1161 - mean_absolute_error: 0.2265 - acc: 0.8442

# %%
# Creating the Confusion Matrix
from sklearn.metrics import confusion_matrix
from lib.helper import AccuracyCalculator

# Predicting the Test set results
y_pred = classifier.predict(X_test)
cm = confusion_matrix(y_test, (y_pred > 0.5))

AccuracyCalculator.class_accuracy(cm)
AccuracyCalculator.optimistic_accuracy(y_pred[:,0], y_test, 100)
risk_hist_df = AccuracyCalculator.risk_hist(y_pred[:,0], y_test)
# Out:
# class_accuracy => accuracy:  0.7096797266124828 risk:  0.1673778389538885
# optimistic_accuracy => risk:  0.03 min pass point:  0.9549216

# %%
(1-risk_hist_df.risk).plot()

# %%
cm
# Out:
# array([[219695,   6080],
#        [ 37525,  30245]])

# %%
dfx = df[df['value']]
p_f = len(dfx[dfx['value_real']]) / len(dfx)
p_r = cm[1,1] / (cm[1,1] + cm[0,1])
print('real prob', p_f , p_r, p_f * p_r)
# Out:
# real prob 0.6685048648185137 0.8326221610461115 0.5566119652150295

# %%
y_all_pred = classifier.predict(sc.transform(X))
y_f_price_real = df['value_real']
cm = confusion_matrix(y_f_price_real, (y_all_pred > 0.8))

AccuracyCalculator.class_accuracy(cm)
AccuracyCalculator.optimistic_accuracy(y_all_pred[:,0], y_f_price_real, 100)
risk_hist_df = AccuracyCalculator.risk_hist(y_all_pred[:,0], y_f_price_real)

print(cm)

(1-risk_hist_df.risk).plot()
# Out:
# class_accuracy => accuracy:  0.5147284930423286 risk:  0.38086232698736516
# optimistic_accuracy => risk:  0.37 min pass point:  0.9549216
# [[1536166   51154]
#  [1264964   83157]]

# %%
dfr = df[df['value']]
dfr['value_real'].astype(int).hist()
print(len(dfr[dfr['value_real']]) / (len(dfr)))
print(len(dfr['value_real']))
# Out:
# 0.6685048648185137
# 676387

# %%
mavgl = str(mavgl)
df2['f_price'] = df2['price'].shift(-window).rolling(window=window).max()
df2['value_real'] = value_real_func2(df2, window, epilson * 2)

X2 = df2[['price', 'mavg10', 'mavg20', 'mavg50', 'mavg80', 'mavg100', 'mavg1000']]

y_all_pred2 = classifier.predict(sc.transform(X2))
y_f_price_real2 = df2['value_real']
cm2 = confusion_matrix(y_f_price_real2, (y_all_pred2 > 0.8))

AccuracyCalculator.class_accuracy(cm2)
AccuracyCalculator.optimistic_accuracy(y_all_pred2[:,0], y_f_price_real2, 100)
print('Unreal prediction:') 
AccuracyCalculator.class_accuracy(confusion_matrix(y_f_price_real2, (y_all_pred2 > -1)))
risk_hist_df2 = AccuracyCalculator.risk_hist(y_all_pred2[:,0], y_f_price_real2)

print(cm2)

(1-risk_hist_df2.risk).plot()
# Out:
# class_accuracy => accuracy:  0.5080599623554719 risk:  0.375
# optimistic_accuracy => risk:  0.23 min pass point:  0.94158226
# Unreal prediction:
# class_accuracy => accuracy:  0.5 risk:  0.4696300037883571
# [[7186  252]
#  [7980  420]]

# %%
import json
import requests

dfo = pd.DataFrame({'price':[]},)

def fetch_oanda_df():
    dfo = pd.DataFrame({'price':[]})
    for candle in get_prices('2018-11-27T08%3A00%3A00.000000000Z'):
        price = candle['ask']['c']
        dfo = dfo.append({'price': price}, ignore_index=True)

    for candle in get_prices('2018-11-27T16%3A00%3A00.000000000Z'):
        price = candle['ask']['c']
        dfo = dfo.append({'price': price}, ignore_index=True)

    for candle in get_prices('2018-11-28T00:23:00.000000000Z'):
        price = candle['ask']['c']
        dfo = dfo.append({'price': price}, ignore_index=True)
    return dfo

def get_prices(fromP):
    global candles
    apiKey = "35d9be2cce688a5f45077f5937a378a1-1d27453afd2533cca5a04fcb877ab7d9"
    headers = {'Authorization': 'Bearer 35d9be2cce688a5f45077f5937a378a1-1d27453afd2533cca5a04fcb877ab7d9'}
    url = "https://api-fxpractice.oanda.com/v3/instruments/EUR_USD/candles?price=BA&from="+fromP+"&granularity=M1"
    r = requests.get(url, headers=headers, stream=True)
    for line in r.iter_lines():
        # filter out keep-alive new lines
        if line:
            line = json.loads(line.decode('utf-8'))
            return line['candles']

# %%
dfo = fetch_oanda_df()

# %%
len(dfo)
# Out:
# 1313

# %%
dfo['price'] = dfo['price'].astype(float)
dataSetOps = DataSetOps()

dataSetOps.df = dfo

dataSetOps.prepare()
dataSetOps.df.head()
y_all_pred3 = classifier.predict(sc.transform(dataSetOps.df[['price', 'mavg10', 'mavg20', 'mavg50', 'mavg80', 'mavg100', 'mavg1000']]))

dataSetOps.df['value_real'] = value_real_func2(dataSetOps.df, window, epilson * 2)
# Out:
# /home/taleh/Projects/TensorTradeBase/lib/predictstrategy.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['f_price_max'] = df['price'].shift(-window).rolling(window=window).max()
# /home/taleh/Projects/TensorTradeBase/lib/predictstrategy.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['f_price_min'] = df['price'].shift(-window).rolling(window=window).mean()
# /home/taleh/Projects/TensorTradeBase/lib/predictstrategy.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['f_price'] = df['price'].shift(-window)
# /home/taleh/Projects/TensorTradeBase/lib/predictstrategy.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['value_real_1'] = df['f_price_max'] - df['price'] > cof
# /home/taleh/Projects/TensorTradeBase/lib/predictstrategy.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['value_real_2'] = df['price'] - df['f_price_min'] < cof
# /home/taleh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
y_all_pred3
cm3 = confusion_matrix(dataSetOps.df['value_real'], (y_all_pred3 > 0.8))

# %%
AccuracyCalculator.class_accuracy(cm3)
# AccuracyCalculator.optimistic_accuracy(y_all_pred3[:,0], y_all_pred3, 100)
# Out:
# class_accuracy => accuracy:  0.5 risk:  1
