# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %load_ext autoreload
# %autoreload 2
# %run '../../main.py'

# %%
dataSetOps = DataSetOps()

dataSetOps.import_years(2016, 2017)

dataSetOps.prepare()
dataSetOps.prepare2(5, 30)

df = dataSetOps.df

# %%
df['value_nr'] = df['value_is_up']
print(len(df))
print(len(df[df.value_nr]))
df['fclass_1'] = (df['mavg10'] > 0) & (df['mavg20'] < 5) & (df['mavg100'] < 5) & (df['mavg1000'] < 5)

prob = len(df[df.value_nr]) / len(df)
dfFclass1 = df[df['fclass_1']]

print(len(dfFclass1))
print(len(dfFclass1[dfFclass1.value_nr]))
# Out:
# 743248
# 203899
# 169585
# 41372

# %%
dfFclass1.value_nr.astype(int).hist()

# %%
from lib.featuredetect.visualite import FeatureDetectVisualite

# %%
featureDetectVisualite = FeatureDetectVisualite(df, 'fclass_1')

# %%
df2 = featureDetectVisualite.prepare()
featureDetectVisualite.make()
# Out:
# '/var/www/html/BMLSLE'

# %%
res2 = featureDetectVisualite.prepare_sub(300)
df3 = pd.DataFrame(data={'value': res2})
df3.plot()
