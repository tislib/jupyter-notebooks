# %%
#import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline 
plt.rcParams['figure.figsize'] = [15, 5]

# %load_ext autoreload
# %autoreload 2
# %run '../../main.py'

dataSetOps = DataSetOps()
dataSetOps.import_tick_data_set('/storage/archive/finance-data/currency/Tick/DAT_ASCII_EURUSD_T_2018.csv')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-47fdccaf182f> in <module>
#      11
#      12 dataSetOps = DataSetOps()
# ---> 13 dataSetOps.import_tick_data_set('/storage/archive/finance-data/currency/Tick/DAT_ASCII_EURUSD_T_2018.csv')
#
# ~/Projects/TensorTradeBase/lib/dataset.py in import_tick_data_set(self, tickPath)
#      25         df.columns = ['date', 'bid', 'ask', '0']
#      26         df.drop('0', axis=1, inplace=True)
# ---> 27         df['time'] = df['date'].map(self.parseTime)
#      28         df['price'] = round(((df['ask'] + df['bid']) / 2) * 1000000) / 1000000
#      29         df['spread'] = round((df['ask'] - df['bid']) * 1000000) / 100
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in map(self, arg, na_action)
# ...

# %%
from datetime import datetime
def parseTime(strx):
    pattern = '%Y%m%d %H%M%S%f'
    return datetime.strptime(strx, pattern)

# %%
data['time'] = data['time_str'].map(parseTime)

# %%
data
# Out:
#                     time_str      bid      ask                    time
# 0         20180101 170015870  1.20100  1.20150 2018-01-01 17:00:15.870
# 1         20180101 170111367  1.20083  1.20133 2018-01-01 17:01:11.367
# 2         20180101 170112367  1.20095  1.20120 2018-01-01 17:01:12.367
# 3         20180101 170132117  1.20075  1.20125 2018-01-01 17:01:32.117
# 4         20180101 170132367  1.20035  1.20085 2018-01-01 17:01:32.367
# 5         20180101 170132617  1.20033  1.20083 2018-01-01 17:01:32.617
# 6         20180101 170133367  1.20026  1.20076 2018-01-01 17:01:33.367
# 7         20180101 170150867  1.20025  1.20075 2018-01-01 17:01:50.867
# 8         20180101 170151117  1.20017  1.20067 2018-01-01 17:01:51.117
# 9         20180101 170159117  1.20030  1.20080 2018-01-01 17:01:59.117
# 10        20180101 170247367  1.20035  1.20085 2018-01-01 17:02:47.367
# 11        20180101 170256867  1.20043  1.20093 2018-01-01 17:02:56.867
# ...
