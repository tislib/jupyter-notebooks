# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline 
plt.rcParams['figure.figsize'] = [15, 5]

import warnings
warnings.filterwarnings('ignore')

# %%
# %load_ext autoreload
# %autoreload 2
# %run '../../main.py'


from lib.helper import Functions
from lib.store.influxstore import InfluxStore

# %%
dataSetOps = DataSetOps()

dataSetOps.import_tick_data_set('/media/taleh/TIsStorage/archive/finance-data/currency/Tick/DAT_ASCII_EURUSD_T_201902.csv')

df = dataSetOps.df

# %%
from lib.engine.btengine import BackTestEngine
from lib.strategy.simple import SimpleStrategy
from lib.algorithm.randoma import RandomAlgorithm
from lib.algorithm.Amp1Algorithm import Amp1Algorithm

snnAlgo1 = Amp1Algorithm(10, 70)
strategy1 = SimpleStrategy()
btengine1 = BackTestEngine()
btengine1.init(df, snnAlgo1, strategy1)

btengine1.run()

btengine1.report()
# Out:
# tick processed  2019-02-01 02:44:47.970000 10000 0.37 % 0 0
# tick processed  2019-02-01 03:56:49.310000 20000 0.73 % 0 0
# tick processed  2019-02-01 04:48:12.871000 30000 1.1 % 0 0
# tick processed  2019-02-01 05:58:35.857000 40000 1.46 % 0 0
# tick processed  2019-02-01 07:14:57.988000 50000 1.83 % 0 0
# tick processed  2019-02-01 08:26:36.038000 60000 2.19 % 0 0
# 2019-02-01 08:40:00.063000 signalled
# 2019-02-01 08:50:00.483000 signalled
# fast closed
# tick processed  2019-02-01 08:59:58.749000 70000 2.56 % -1.3799999999997148 2
# 2019-02-01 09:00:00.087000 signalled
# 2019-02-01 09:10:00.106000 signalled
# fast closed
# tick processed  2019-02-01 09:43:30.550000 80000 2.92 % -1.1799999999997368 4
# 2019-02-01 10:10:00.072000 signalled
# 2019-02-01 10:20:00.207000 signalled
# tick processed  2019-02-01 10:27:00.653000 90000 3.29 % -1.0099999999999554 5
# 2019-02-01 10:40:00.599000 signalled
# tick processed  2019-02-01 11:14:30.019000 100000 3.65 % -1.7799999999996707 7
# ...

# %%
# Out:
#         amp    close      max      min                time
# 0  -0.85579  1.14421  0.00000  2.00000 2019-02-01 00:00:00
# 1  -1.14397  1.14402  1.14428  1.14397 2019-02-01 00:10:00
# 2   0.00031  1.14412  1.14411  1.14397 2019-02-01 00:20:00
# 3   0.00012  1.14408  1.14413  1.14399 2019-02-01 00:30:00
# 4   0.00039  1.14376  1.14408  1.14374 2019-02-01 00:40:00
# 5   0.00065  1.14380  1.14381  1.14343 2019-02-01 00:50:00
# 6   0.00038  1.14367  1.14381  1.14343 2019-02-01 01:00:00
# 7   0.00030  1.14363  1.14380  1.14351 2019-02-01 01:10:00
# 8   0.00033  1.14380  1.14381  1.14347 2019-02-01 01:20:00
# 9   0.00004  1.14395  1.14403  1.14377 2019-02-01 01:30:00
# 10  0.00017  1.14399  1.14410  1.14386 2019-02-01 01:40:00
# 11  0.00025  1.14393  1.14402  1.14385 2019-02-01 01:50:00
# 12  0.00009  1.14419  1.14438  1.14393 2019-02-01 02:00:00
# 13  0.00038  1.14442  1.14460  1.14400 2019-02-01 02:10:00
# 14  0.00037  1.14439  1.14478  1.14423 2019-02-01 02:20:00
# ...

# %%
import time

# %%
1548979200000000
# Out:
# 1548979200000000

# %%
len(df)
# Out:
# 2736589
